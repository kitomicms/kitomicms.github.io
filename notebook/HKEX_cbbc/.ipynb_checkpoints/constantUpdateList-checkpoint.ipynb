# %%
import pandas as pd
import urllib
import requests
from bs4 import BeautifulSoup as bs
import datetime
#https://www.hkex.com.hk/chi/cbbc/newissue/newlaunch_c.htm
import functions

# %%
url_cbbcs = 'http://www.hkex.com.hk/eng/market/sec_tradinfo/stockcode/eisdcbbc.htm'
thepage_cbbcs = urllib.urlopen(url_cbbcs)
soup_cbbcs = bs(thepage_cbbcs,"html.parser")

# %%
records = []
for tr in soup_cbbcs.findAll("tr"):
    trs = tr.findAll("td")
    record = []
    try:
        record.append(trs[0].text)
        #record.append(trs[1].a['href'])
        record.append(trs[1].a['href'])
        record.append((trs[2].text))
        record.append(trs[3].text)
        #record.append(datetime.datetime.strptime(trs[3],'%d/%m/%y'))
        records.append(record)
    except:
        pass
    
df = pd.DataFrame(data=records)
#housekeep the df
df.columns = ['STOCK CODE', 'NAME','LOT','EXPIRY']
df['LOT'] = df['LOT'].str.replace(',','').astype('int')
df['EXPIRY'] = df['EXPIRY'].apply(lambda x:datetime.datetime.strptime(x, '%d/%m/%Y'))
df['STOCK CODE'] = df['STOCK CODE'].astype('int')

# %%
df.tail()
# Out:
#       STOCK CODE                                               NAME    LOT  \
# 1977       69986  ../../../invest/company/profile_page_e.asp?Wid...   1000
# 1978       69987  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 1979       69993  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 1980       69994  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 1981       69999  ../../../invest/company/profile_page_e.asp?Wid...  10000
#
#          EXPIRY
# 1977 2017-04-21
# 1978 2016-12-07
# 1979 2017-02-27
# 1980 2016-12-30
# 1981 2016-12-29

# %%
searchList = list(df['STOCK CODE'][0:201])

# %%
searchListResult = functions.cbbc_loop(searchList)

# %%
df['underlying'] = 'None'

# %%
df.loc[0:200,'underlying'] = searchListResult

# %%
df
# Out:
#       STOCK CODE                                               NAME    LOT  \
# 0          60000  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 1          60001  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 2          60002  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 3          60003  ../../../invest/company/profile_page_e.asp?Wid...   2000
# 4          60004  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 5          60005  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 6          60006  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 7          60007  ../../../invest/company/profile_page_e.asp?Wid...  20000
# 8          60008  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 9          60009  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 10         60010  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 11         60011  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 12         60012  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 13         60013  ../../../invest/company/profile_page_e.asp?Wid...  20000
# 14         60014  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 15         60015  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 16         60018  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 17         60020  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 18         60021  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 19         60025  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 20         60031  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 21         60034  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 22         60035  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 23         60036  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 24         60037  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 25         60038  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 26         60039  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 27         60042  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 28         60044  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 29         60049  ../../../invest/company/profile_page_e.asp?Wid...  10000
# ...          ...                                                ...    ...
# 1952       69885  ../../../invest/company/profile_page_e.asp?Wid...   4000
# 1953       69886  ../../../invest/company/profile_page_e.asp?Wid...   4000
# 1954       69891  ../../../invest/company/profile_page_e.asp?Wid...  10000
# 1955       69900  ../../../invest/company/profile_page_e.asp?Wid...  10000
#