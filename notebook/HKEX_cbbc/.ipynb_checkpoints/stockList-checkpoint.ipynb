# %%
import pandas as pd
import urllib
import requests
from bs4 import BeautifulSoup as bs
import datetime
#https://www.hkex.com.hk/chi/cbbc/newissue/newlaunch_c.htm
import functions

# %%
url1 = 'http://www.hkex.com.hk/chi/market/sec_tradinfo/stockcode/eisdeqty_c.htm'
thepage1 = urllib.urlopen(url1)
soup1 = bs(thepage1,"html.parser")
url2 = 'http://www.hkex.com.hk/eng/market/sec_tradinfo/stockcode/eisdeqty.htm'
thepage2 = urllib.urlopen(url2)
soup2 = bs(thepage2,"html.parser")

# %%
records1 = []
for tr in soup1.findAll("tr"):
    trs = tr.findAll("td")
    record1 = []
    try:
        for x in range(0,7):
            record1.append(trs[x].text)
        records1.append(record1)
    except:
        pass
records2 = []
for tr in soup2.findAll("tr"):
    trs = tr.findAll("td")
    record2 = []
    try:
        for x in range(0,7):
            record2.append(trs[x].text)
        records2.append(record2)
    except:
        pass
dfc = pd.DataFrame(data=records1)
dfe = pd.DataFrame(data=records2)

# %%
dfe['ChineseName'] = dfc[1]

# %%
dfe.columns = ['StockCode','EnglishName','Lot','Note1','Note2','Note3','Note4','ChineseName']
df = dfe.reindex(columns=['StockCode','EnglishName','ChineseName','Lot','Note1','Note2','Note3','Note4'])

# %%
df.drop(df.index[0:3])
# Out:
#      StockCode      EnglishName      ChineseName     Lot Note1 Note2 Note3  \
# 3        00001     CKH HOLDINGS               長和     500     #     H     O
# 4        00002     CLP HOLDINGS             中電控股     500     #     H     O
# 5        00003   HK & CHINA GAS           香港中華煤氣   1,000     #     H     O
# 6        00004   WHARF HOLDINGS            九龍倉集團   1,000     #     H     O
# 7        00005    HSBC HOLDINGS             匯豐控股     400     #     H     O
# 8        00006     POWER ASSETS             電能實業     500     #     H     O
# 9        00007     HOIFU ENERGY             凱富能源   2,000     #
# 10       00008             PCCW             電訊盈科   1,000     #     H
# 11       00009     NINE EXPRESS             九號運通   6,000     #
# 12       00010  HANG LUNG GROUP             恒隆集團   1,000     #     H
# 13       00011   HANG SENG BANK             恒生銀行     100     #     H     O
# 14       00012   HENDERSON LAND             恒基地產   1,000     #     H     O
# 15       00014        HYSAN DEV             希慎興業   1,000     #     H
# 16       00015    VANTAGE INT'L             盈信控股   2,000     #
# 17       00016          SHK PPT            新鴻基地產   1,000     #     H     O
# 18       00017    NEW WORLD DEV            新世界發展   1,000     #     H     O
# 19       00018   ORIENTAL PRESS           東方報業集團   2,000     #
# 20       00019  SWIRE PACIFIC A          太古股份公司Ａ     500     #     H     O
# 21       00020         WHEELOCK              會德豐   1,000     #     H
# 22       00021    GREAT CHI PPT          大中華地產控股   5,000     #
# 23       00022            MEXAN             茂盛控股  40,000     #
# 24       00023   BANK OF E ASIA             東亞銀行     200     #     H     O
# 25       00024          BURWILL             寶威控股   2,000     #
# 26       00025  CHEVALIER INT'L  CHEVALIER INT'L   2,000     #     H
# 27       00026  CHINA MOTOR BUS             中華汽車     200     #     H
# 28       00027       GALAXY ENT             銀河娛樂   1,000     #     H     O
# 29       00028          TIAN AN               天安   1,000     #     H
# 30       00029     DYNAMIC HOLD             達力集團   2,000     #
# 31       00030   BAN LOONG HOLD           萬隆控股集團   2,000     #
# 32       00031  CHINA AEROSPACE             航天控股   2,000     #     H
# ...        ...              ...              ...     ...   ...   ...   ...
# 1662     06818         CEB BANK           中國光大銀行   1,000     #     H
# 1663     06822     KING'S FLAIR             科勁國際   4,000     #
# 1664     06823           HKT-SS          香港電訊-SS   1,000     #     H
# 1665     06826    HAOHAI BIOTEC           昊海生物科技     100     #     H
# 1666     06828     BLUE SKY PWR             藍天威力   8,000     #     H
# 1667     06830    HUAZHONG IN-V             華眾車載   2,000     #
# 1668     06833     SINCO PHARMA            興科蓉醫藥   4,000     #
# 1669     06836    TIANYUN INT'L           天韻國際控股   2,000     #
# 1670     06837      HAITONG SEC             海通證券     400     #     H     O
# 1671     06838            WINOX              盈利時   2,000     #
# 1672     06839     YUNNAN WATER             雲南水務   1,000     #     H
# 1673     06858        HONMAGOLF            本間高爾夫     500     #
# 1674     06863    HUISHAN DAIRY             輝山乳業   1,000     #     H
# 1675     06865       FLAT GLASS            福萊特玻璃   1,000     #
# 1676     06866      ZUOLI M-FIN             佐力小貸   2,000     #
# 1677     06868            TENFU               天福   1,000     #     H
# 1678     06869             YOFC           長飛光纖光纜     500     #     H
# 1679     06878     DIFFER GROUP           鼎豐集團控股   2,000     #     H
# 1680     06880      TEMPUS HOLD             騰邦控股   2,000     #
# 1681     06881              CGS             中國銀河     500     #     H
# 1682     06882     EGL HOLDINGS              東瀛遊   2,000     #
# 1683     06886             HTSC             HTSC     200     #     H
# 1684     06888         FREETECH         英達公路再生科技   1,000     #
# 1685     06889      DYNAM JAPAN      DYNAM JAPAN     200     #     H
# 1686     06893    HINSANG GROUP             衍生集團   2,000     #
# 1687     06896    GOLDEN THROAT              金嗓子     500     #
# 1688     06898    CHINA ALUMCAN             中國鋁罐   2,000     #
# 1689     06899          OURGAME               聯眾   1,000     #     H
# 1690     80737  HOPEWELL INFR-R         合和公路基建－Ｒ     500     #     H
# 1691     84602  ICBC CNHPREF1-R  ICBC CNHPREF1-R  10,000
#
#      Note4
# 3        F
# 4        F
# 5        F
# 6        F
# 7        F
# 8        F
# 9
# 10
# 11
# 12
# 13       F
# 14       F
# 15
# 16
# 17       F
# 18       F
# 19
# 20       F
# 21
# 22
# 23
# 24       F
# 25
# 26
# 27
# 28
# 29
# 30
# 31
# 32
# ...    ...
# 1662
# 1663
# 1664
# 1665
# 1666
# 1667
# 1668
# 1669
# 1670     F
# 1671
# 1672
# 1673
# 1674     F
# 1675
# 1676
# 1677
# 1678
# 1679
# 1680
# 1681
# 1682
# 1683     F
# 1684
# 1685
# 1686
# 1687
# 1688
# 1689
# 1690
# 1691
#
# [1689 rows x 8 columns]
