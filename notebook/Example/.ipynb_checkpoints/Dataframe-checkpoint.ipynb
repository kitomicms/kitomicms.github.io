# %%
import pandas as pd
import numpy as np

# %%
#filter rows and update value of a column
source = pd.read_html('http://www.hkex.com.hk/eng/cbbc/expire/expiring.htm')

df = source[0][10:]
df1 = df.drop(df.columns[12:],axis=1)

df1.columns = (source[0].iloc[9])[0:12]

df1['HS Issuer'] = 'None'

df1.loc[df1['Issuer'] == 'HS',['HS Issuer']] = 'Yes'

df1
# Out:
# 9     No. CBBC Code        CBBC Name Issuer Underlying Bull/Bear  \
# 10     1.     61449   HS#GEG RC1611H     HS      00027      Bull
# 11     2.     62661  HS#HKEX RC1611H     HS      00388      Bull
# 12     3.     64861  HS#C MOBRP1611B     HS      00941      Bear
# 13     4.     64928  HS#PETCHRP1611B     HS      00857      Bear
# 14     5.     64970  HS#TENCTRC1611B     HS      00700      Bull
# 15     6.     65038  HS#CP&CCRP1611B     HS      00386      Bear
# 16     7.     65900  UB#C MOBRC1611A     UB      00941      Bull
# 17     8.     66970   HS#GEG RP1611A     HS      00027      Bear
# 18     9.     66987  HS#SANDSRP1611A     HS      01928      Bear
# 19    10.     68376   HS#GEG RC1611G     HS      00027      Bull
# 20    11.     68406  HS#CITSERC1611C     HS      06030      Bull
# 21    12.     68877  HS#C MOBRC1611D     HS      00941      Bull
# 22    13.     63472  JP#CSA50RC1611A     JP      02822      Bull
# ...
