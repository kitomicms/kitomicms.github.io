# %%
#//*[@id="pageContent"]/table/tbody/tr[3]/td[1]
from lxml import html,cssselect
import requests
import sys

# %%
page = requests.get('http://www.analystz.hk/cbbc/cbbc-outstanding-quantity-analysis.php')
tree = html.fromstring(page.content)

path = '//*[@id="pageContent"]/table/tr/td[contains(@class,"tBody2")]/text()'

quote = tree.xpath(path)
    
price_sign = tree.cssselect("span span img")
    
    
string = ""
    
    
for foo in quote:
    print foo

#print name + " " + string + price_sign[0].attrib['alt']
# Out:
# 24588
# 24788
# 200
# HS
# 15000
# 20160629
# 12.21
# 23328
# 23578
# 250
# HS
# 20000
# 20161028
# 16.17
# 23000
# 23200
# 200
# MB
# 15000
# 20160530
# 5.58
# 22488
# 22688
# 200
# HS
# 15000
# 20160929
# 20.25
# 22288
# 22488
# 200
# HS
# 15000
# 20161229
# 22
# 22150
# 22350
# 200
# CS
# 10000
# 20160530
# 5.21
# 22088
# 22288
# 200
# HS
# 15000
# 20170227
# 24.26
# 22000
# 22200
# 200
# CS
# 10000
# 20160530
# 5.1
# 22000
# 22200
# 200
# UB
# 10000
# 20160830
# 21.43
# 21950
# 22200
# 250
# CS
# 12000
# 20160629
# 16.56
# 21950
# 22150
# 200
# UB
# 10000
# 20160830
# 21.47
# 21850
# 22050
# 200
# UB
# 12000
# 20160530
# 6.62
# 21850
# 22050
# 200
# CS
# 10000
# 20160728
# 18.23
# 21850
# 22050
# 200
# MB
# 20000
# 20160929
# 33.33
# 21750
# 21950
# 200
# CS
# 10000
# 20160530
# 4.68
# 21700
# 21900
# 200
# UB
# 10000
# 20160530
# 4.22
# 21700
# 21900
# 200
# JP
# 10000
# 20160530
# 4.82
# 21700
# 21900
# 200
# CS
# 10000
# 20160929
# 23.49
# 21700
# 21900
# 200
# BP
# 10000
# ...
